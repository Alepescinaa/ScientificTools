# %% [markdown]
# <a href="https://colab.research.google.com/github/Alepescinaa/ScientificTools/blob/main/Project1/Cp1/PINN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises: physics-informed neural network
#
# Exercise on the implementation of physics-informed neural network.
#
# Date: 2024
#
# Course: 056936 - SCIENTIFIC COMPUTING TOOLS FOR ADVANCED MATHEMATICAL MODELLING (PAGANI STEFANO) [2023-24].
#
# Example adapted from this [notebook](https://colab.research.google.com/drive/1qBrbgevkSBqqYc8bOPiaoJG1MBrBrluN?usp=share_link).

# %% [markdown]
# Let us consider the problem
#
# \begin{aligned}
#   & v_f *\sqrt(\nabla u\cdot D\nabla u) =1  \,, \quad (x,y) \in [-1.5,1.5] \times [-1.5,1.5]\,\\
# \end{aligned}
#
# where $\nu$ is unknown. We consider the PINN framework for solving the state/parameter estimation.

# %%
# import required libraries

import tensorflow as tf
import numpy as np
import scipy.io
from tensorflow import keras
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# !pip -q install pyDOE
from pyDOE import lhs  # for latin hypercube sampling
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyDOE (setup.py) ... done

# %%
# set seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# %%
# !git clone https://github.com/Alepescinaa/ScientificTools
# %cd ScientificTools/Project1/Cp2
# Out:
# Cloning into 'ScientificTools'...
# remote: Enumerating objects: 280, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 280 (delta 32), reused 1 (delta 1), pack-reused 156
# Receiving objects: 100% (280/280), 59.83 MiB | 8.50 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/ScientificTools/Project1/Cp2

# %%
# loading of the dataset

CP2data = np.load("CP2data.npz")
CP2data = CP2data['arr_0']

# %%
# loading of the estimate

CP2estimate = np.load("CP2estimate.npz")
CP2estimate = CP2estimate['arr_0']

# %%
theta_fiber = CP2estimate[ind_disp][0]
a_ratio  = CP2estimate[ind_disp][1]
y0 = CP2estimate[ind_disp][2]

# %% [markdown]
# # Solution

# %%
X, Y = np.meshgrid(np.linspace(-1.5,1.5,1501), np.linspace(-1.5,1.5,1501))
X_flat = tf.convert_to_tensor(np.hstack((X.flatten()[:,None],Y.flatten()[:,None])),dtype=tf.float64)
x0 = 1.5

theta0 = np.pi/2 - theta_fiber
a = np.array([np.cos(theta0), np.sin(theta0)]).T
b = np.array([np.cos(theta0-np.pi/2), np.sin(theta0-np.pi/2)]).T

D = ( (1/a_ratio)*np.tensordot( a, a,  axes=0) + np.tensordot( b, b,  axes=0)  )
print(D)

D_inv = np.linalg.inv(D)
sigma_11 = D_inv[0][0]
sigma_12 = D_inv[0][1]
sigma_21 = D_inv[1][0]
sigma_22 = D_inv[1][1]

#activation_time = anysotropic_FMM( x0 , y0 , X, Y, sigma_11,sigma_12, sigma_21, sigma_22 )
# Out:
# [[ 0.98915396 -0.08798785]
#  [-0.08798785  0.28620407]]

# %%
# PINN loss function
def loss(xcl,ycl,xmeas,ymeas,umeas,param):
    umeas_pred = PINN(tf.concat([xmeas,ymeas],1))
    r_pred   = r_PINN(xcl,ycl,param)

    # loss components
    mse_meas  = tf.reduce_mean(tf.pow(umeas-umeas_pred,2))
    mse_r  = tf.reduce_mean(tf.pow(r_pred,2))

    return mse_r+mse_meas # mse_0+mse_r+mse_lb+mse_ub

# neural network weight gradients
@tf.function
def grad(model,xcl,ycl,xmeas,ymeas,umeas,param):
    with tf.GradientTape(persistent=True) as tape:
        loss_value = loss(xcl,ycl,xmeas,ymeas,umeas,param)
        grads = tape.gradient(loss_value,model.trainable_variables)
        grad_param = tape.gradient(loss_value,param)
    return loss_value, grads, grad_param

# %%
# collocation points
Ncl = 5000
Xcl = lhs(2,Ncl)
xcl = tf.expand_dims(tf.cast(-1.5+(3.0)*Xcl[:,0],dtype=tf.float64),axis=-1)
ycl = tf.expand_dims(tf.cast(-1.5+(3.0)*Xcl[:,1],dtype=tf.float64),axis=-1)
X_coll = tf.concat([xcl,ycl],1)

# measurement points
ind_disp=5
xmeas = CP2data[ind_disp][0]
ymeas = CP2data[ind_disp][1]
tmeas = CP2data[ind_disp][2]
xmeas = tf.constant(xmeas.reshape(20, 1), dtype=tf.float64)
ymeas = tf.constant(ymeas.reshape(20, 1), dtype=tf.float64)
tmeas = tf.constant(tmeas.reshape(20, 1), dtype=tf.float64)

# %%
# training loop

# initialize new instance of NN
PINN = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='tanh', input_shape=(2,),kernel_initializer="glorot_normal",dtype=tf.float64),
    tf.keras.layers.Dense(32, activation='tanh',kernel_initializer="glorot_normal",dtype=tf.float64),
    tf.keras.layers.Dense(1,activation=None,kernel_initializer="glorot_normal",dtype=tf.float64)
])

# %%
# residual computation based on AD
@tf.function
def r_PINN(x,y,param):
    u    = PINN(tf.concat([x,y], 1))
    u_x  = tf.gradients(u,x)[0]
    u_y  = tf.gradients(u,y)[0]
    x0 = 1.5
    theta0 = np.pi/2 - param[0]
    a = np.array([np.cos(theta0), np.sin(theta0)]).T
    b = np.array([np.cos(theta0-np.pi/2), np.sin(theta0-np.pi/2)]).T
    D = ( (1/param[])*np.tensordot( a, a,  axes=0) + np.tensordot( b, b,  axes=0)  )
    return  param*(tf.sqrt(sigma_f*u_x**2 + sigma_s*u_y**2) )-1


# Adam optimizer
tf_optimizer = tf.keras.optimizers.Adam(learning_rate=0.003,beta_1=0.99)

# parameter variable
param = tf.Variable(0.1,trainable=True,dtype=tf.float64)
for iter in range(20000):


  # compute gradients using AD
  loss_value,grads,grad_param = grad(PINN,xcl,ycl,xmeas,ymeas,tmeas,param)

  # update neural network weights
  tf_optimizer.apply_gradients(zip(grads+[grad_param],PINN.trainable_variables+[param]))



  # display intermediate results
  if ((iter+1) % 200 == 0):
    print('iter =  '+str(iter+1))
    print('loss = {:.4f}'.format(loss_value))
    print('coefficient estimate = {:.4f}'.format((param.numpy())))
    PINN_flat = PINN(X_flat)
    mse = 0.0
    time_pred = tf.reshape(PINN_flat, (1501, 1501))
    xmeas=xmeas.numpy().squeeze()
    ymeas=ymeas.numpy().squeeze()
    tmeas=tmeas.numpy().squeeze()
    time_pred=time_pred.numpy()
    for k in range(20):
            i, j = np.where((X == xmeas[k]) & (Y == ymeas[k]))
            mse+= (time_pred[i, j] - tmeas[k]) ** 2
    print('mse error: %.4e' % (np.sqrt(mse/20)))
    xmeas = tf.constant(xmeas.reshape(20, 1), dtype=tf.float64)
    ymeas = tf.constant(ymeas.reshape(20, 1), dtype=tf.float64)
    tmeas = tf.constant(tmeas.reshape(20, 1), dtype=tf.float64)
# Out:
# iter =  200
# loss = 1.0018
# coefficient estimate = 0.5593
# <ipython-input-151-db87901cdf8c>:41: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('mse error: %.4e' % (np.sqrt(mse/20)))
# mse error: 4.5650e-02
# iter =  400
# loss = 0.9999
# coefficient estimate = 0.8507
# mse error: 1.3076e-02
# iter =  600
# loss = 0.9999
# coefficient estimate = 1.0558
# mse error: 7.2159e-03
# iter =  800
# loss = 0.9998
# coefficient estimate = 1.2502
# mse error: 8.3771e-03
# iter =  1000
# loss = 0.9997
# coefficient estimate = 1.4952
# mse error: 9.1105e-03
# iter =  1200
# loss = 0.9997
# coefficient estimate = 1.7926
# mse error: 1.1130e-02
# iter =  1400
# loss = 0.9996
# coefficient estimate = 2.1557
# mse error: 1.3317e-02
# iter =  1600
# loss = 0.9994
# coefficient estimate = 2.5914
# mse error: 1.6110e-02
# iter =  1800
# loss = 0.9992
# coefficient estimate = 3.1043
# mse error: 1.9414e-02
# iter =  2000
# loss = 0.9989
# coefficient estimate = 3.6948
# mse error: 2.3115e-02
# iter =  2200
# loss = 0.9983
# coefficient estimate = 4.3632
# mse error: 2.6843e-02
# iter =  2400
# loss = 0.9942
# coefficient estimate = 5.2196
# mse error: 5.6946e-02
# iter =  2600
# loss = 0.9242
# coefficient estimate = 6.4566
# mse error: 1.4101e-01
# iter =  2800
# loss = 0.4281
# coefficient estimate = 7.7565
# mse error: 2.1269e-01
# iter =  3000
# loss = 0.1235
# coefficient estimate = 8.6798
# mse error: 1.1689e-01
# iter =  3200
# loss = 0.0698
# coefficient estimate = 9.1175
# mse error: 4.9964e-02
# iter =  3400
# loss = 0.0477
# coefficient estimate = 9.3412
# mse error: 2.0566e-02
# iter =  3600
# loss = 0.0384
# coefficient estimate = 9.4658
# mse error: 1.3916e-02
# iter =  3800
# loss = 0.0330
# coefficient estimate = 9.5465
# mse error: 1.2076e-02
# iter =  4000
# loss = 0.0294
# coefficient estimate = 9.6175
# mse error: 1.1991e-02
# iter =  4200
# loss = 0.0272
# coefficient estimate = 9.6812
# mse error: 8.9458e-03
# iter =  4400
# loss = 0.0257
# coefficient estimate = 9.7343
# mse error: 8.2213e-03
# iter =  4600
# loss = 0.0243
# coefficient estimate = 9.7803
# mse error: 6.6768e-03
# iter =  4800
# loss = 0.0228
# coefficient estimate = 9.8253
# mse error: 5.9941e-03
# iter =  5000
# loss = 0.0213
# coefficient estimate = 9.8737
# mse error: 5.7939e-03
# iter =  5200
# loss = 0.0199
# coefficient estimate = 9.9257
# mse error: 6.2920e-03
# iter =  5400
# loss = 0.0188
# coefficient estimate = 9.9814
# mse error: 6.1201e-03
# iter =  5600
# loss = 0.0178
# coefficient estimate = 10.0395
# mse error: 6.2965e-03
# iter =  5800
# loss = 0.0169
# coefficient estimate = 10.0970
# mse error: 6.4623e-03
# iter =  6000
# loss = 0.0162
# coefficient estimate = 10.1501
# mse error: 6.6432e-03
# iter =  6200
# loss = 0.0156
# coefficient estimate = 10.1960
# mse error: 6.2853e-03
# iter =  6400
# loss = 0.0151
# coefficient estimate = 10.2338
# mse error: 5.9754e-03
# iter =  6600
# loss = 0.0145
# coefficient estimate = 10.2647
# mse error: 5.5839e-03
# iter =  6800
# loss = 0.0140
# coefficient estimate = 10.2897
# mse error: 5.1563e-03
# iter =  7000
# loss = 0.0135
# coefficient estimate = 10.3106
# mse error: 4.5226e-03
# iter =  7200
# loss = 0.0130
# coefficient estimate = 10.3281
# mse error: 4.1410e-03
# iter =  7400
# loss = 0.0126
# coefficient estimate = 10.3430
# mse error: 3.7562e-03
# iter =  7600
# loss = 0.0121
# coefficient estimate = 10.3563
# mse error: 4.1802e-03
# iter =  7800
# loss = 0.0117
# coefficient estimate = 10.3694
# mse error: 3.3642e-03
# iter =  8000
# loss = 0.0113
# coefficient estimate = 10.3837
# mse error: 3.5605e-03
# iter =  8200
# loss = 0.0109
# coefficient estimate = 10.4021
# mse error: 3.1111e-03
# iter =  8400
# loss = 0.0105
# coefficient estimate = 10.4283
# mse error: 3.5267e-03
# iter =  8600
# loss = 0.0101
# coefficient estimate = 10.4619
# mse error: 3.2015e-03
# iter =  8800
# loss = 0.0098
# coefficient estimate = 10.4954
# mse error: 2.5782e-03
# iter =  9000
# loss = 0.0095
# coefficient estimate = 10.5233
# mse error: 1.9761e-03
# iter =  9200
# loss = 0.0092
# coefficient estimate = 10.5476
# mse error: 2.7343e-03
# iter =  9400
# loss = 0.0090
# coefficient estimate = 10.5711
# mse error: 2.7945e-03
# iter =  9600
# loss = 0.0087
# coefficient estimate = 10.5952
# mse error: 2.9297e-03
# iter =  9800
# loss = 0.0085
# coefficient estimate = 10.6135
# mse error: 2.2176e-03
# iter =  10000
# loss = 0.0083
# coefficient estimate = 10.6239
# mse error: 2.7639e-03
# iter =  10200
# loss = 0.0081
# coefficient estimate = 10.6274
# mse error: 2.9137e-03
# iter =  10400
# loss = 0.0079
# coefficient estimate = 10.6250
# mse error: 3.1784e-03
# iter =  10600
# loss = 0.0077
# coefficient estimate = 10.6198
# mse error: 2.5496e-03
# iter =  10800
# loss = 0.0076
# coefficient estimate = 10.6142
# mse error: 2.6674e-03
# iter =  11000
# loss = 0.0074
# coefficient estimate = 10.6097
# mse error: 2.8325e-03
# iter =  11200
# loss = 0.0073
# coefficient estimate = 10.6068
# mse error: 3.2974e-03
# iter =  11400
# loss = 0.0072
# coefficient estimate = 10.6055
# mse error: 3.2372e-03
# iter =  11600
# loss = 0.0071
# coefficient estimate = 10.6061
# mse error: 2.4638e-03
# iter =  11800
# loss = 0.0069
# coefficient estimate = 10.6092
# mse error: 3.2057e-03
# iter =  12000
# loss = 0.0068
# coefficient estimate = 10.6155
# mse error: 2.5510e-03
# iter =  12200
# loss = 0.0067
# coefficient estimate = 10.6256
# mse error: 2.7771e-03
# iter =  12400
# loss = 0.0066
# coefficient estimate = 10.6400
# mse error: 2.3485e-03
# iter =  12600
# loss = 0.0065
# coefficient estimate = 10.6590
# mse error: 2.3358e-03
# iter =  12800
# loss = 0.0064
# coefficient estimate = 10.6826
# mse error: 2.5339e-03
# iter =  13000
# loss = 0.0063
# coefficient estimate = 10.7106
# mse error: 2.8674e-03
# iter =  13200
# loss = 0.0062
# coefficient estimate = 10.7429
# mse error: 2.8359e-03
# iter =  13400
# loss = 0.0061
# coefficient estimate = 10.7793
# mse error: 2.5675e-03
# iter =  13600
# loss = 0.0061
# coefficient estimate = 10.8199
# mse error: 2.4833e-03
# iter =  13800
# loss = 0.0060
# coefficient estimate = 10.8648
# mse error: 2.3278e-03
# iter =  14000
# loss = 0.0059
# coefficient estimate = 10.9144
# mse error: 2.1492e-03
# iter =  14200
# loss = 0.0058
# coefficient estimate = 10.9693
# mse error: 2.5211e-03
# iter =  14400
# loss = 0.0058
# coefficient estimate = 11.0294
# mse error: 2.8137e-03
# iter =  14600
# loss = 0.0057
# coefficient estimate = 11.0942
# mse error: 2.7663e-03
# iter =  14800
# loss = 0.0056
# coefficient estimate = 11.1643
# mse error: 2.1919e-03
# iter =  15000
# loss = 0.0055
# coefficient estimate = 11.2360
# mse error: 2.5597e-03
# iter =  15200
# loss = 0.0055
# coefficient estimate = 11.2949
# mse error: 2.7429e-03
# iter =  15400
# loss = 0.0054
# coefficient estimate = 11.3622
# mse error: 2.5737e-03
# iter =  15600
# loss = 0.0053
# coefficient estimate = 11.4287
# mse error: 2.5726e-03
# iter =  15800
# loss = 0.0052
# coefficient estimate = 11.4952
# mse error: 2.8224e-03
# iter =  16000
# loss = 0.0052
# coefficient estimate = 11.5627
# mse error: 2.1477e-03
# iter =  16200
# loss = 0.0051
# coefficient estimate = 11.6288
# mse error: 2.5553e-03
# iter =  16400
# loss = 0.0051
# coefficient estimate = 11.6925
# mse error: 2.3076e-03
# iter =  16600
# loss = 0.0050
# coefficient estimate = 11.7538
# mse error: 2.9199e-03
# iter =  16800
# loss = 0.0050
# coefficient estimate = 11.8129
# mse error: 2.7074e-03
# iter =  17000
# loss = 0.0049
# coefficient estimate = 11.8696
# mse error: 2.2002e-03
# iter =  17200
# loss = 0.0049
# coefficient estimate = 11.9240
# mse error: 2.7071e-03
# iter =  17400
# loss = 0.0048
# coefficient estimate = 11.9757
# mse error: 2.3514e-03
# iter =  17600
# loss = 0.0048
# coefficient estimate = 12.0245
# mse error: 2.2367e-03
# iter =  17800
# loss = 0.0048
# coefficient estimate = 12.0706
# mse error: 2.9138e-03
# iter =  18000
# loss = 0.0047
# coefficient estimate = 12.1141
# mse error: 2.4302e-03
# iter =  18200
# loss = 0.0047
# coefficient estimate = 12.1555
# mse error: 2.1825e-03
# iter =  18400
# loss = 0.0047
# coefficient estimate = 12.1954
# mse error: 2.4951e-03
# iter =  18600
# loss = 0.0046
# coefficient estimate = 12.2343
# mse error: 2.6092e-03
# iter =  18800
# loss = 0.0046
# coefficient estimate = 12.2726
# mse error: 2.3723e-03
# iter =  19000
# loss = 0.0045
# coefficient estimate = 12.3109
# mse error: 2.1929e-03
# iter =  19200
# loss = 0.0045
# coefficient estimate = 12.3496
# mse error: 2.7173e-03
# iter =  19400
# loss = 0.0045
# coefficient estimate = 12.3887
# mse error: 2.8579e-03
# iter =  19600
# loss = 0.0044
# coefficient estimate = 12.4284
# mse error: 2.6380e-03
# iter =  19800
# loss = 0.0044
# coefficient estimate = 12.4683
# mse error: 2.3116e-03
# iter =  20000
# loss = 0.0044
# coefficient estimate = 12.5076
# mse error: 2.2397e-03

# %%
#Display results

fig = plt.figure(figsize=(16,9),dpi=150)
#fig = plt.figure()
#fig.subplots_adjust(wspace=0.3)
plt.style.use('default')
ax = fig.add_subplot(1,3,1)
ax.set_aspect(1)
im = plt.pcolor(X_plot, Y_plot, u_true)
plt.scatter(xmeas,ymeas,marker='x',s=3)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(im,cax=cax)
#ax.set_yticklabels(['-1.0','-0.6','-0.2','0.2','0.6','1.0'])
ax.set_title('Exact Solution',fontsize=16)

ax = fig.add_subplot(1,3,2)
ax.set_aspect(1)
im = plt.pcolor(X_plot, Y_plot, np.reshape(PINN_flat,(N_h,N_h)))
plt.scatter(xmeas,ymeas,marker='x',s=3)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(im,cax=cax)
ax.set_title('PINN Prediction'.format(err),fontsize=16)

ax = fig.add_subplot(1,3,3)
ax.set_aspect(1)
im = plt.pcolor(X_plot, Y_plot, np.abs( np.reshape(PINN_flat,(N_h,N_h)) -u_true ) )
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(im,cax=cax)
ax.set_title('L2 error = {:.4f}'.format(err),fontsize=16)

# %% [markdown]
# scale parametri
# inizializzazione parametri incogniti ma nontrainable
